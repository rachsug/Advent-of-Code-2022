# %%
#-------------SOLUTION_1--------------
from collections import defaultdict
def supplyStacks(txt_file):
    with open(txt_file) as f:
        lines = f.read()
        f.seek(0)
        actl_lines = f.readlines()
    
    d = {}
    res = ''
    
    for i in range(9):
        stack_no = 'stack_' + str(i+1)

        for j in range((i*4)+1, 8*36, 36):
            d.setdefault(stack_no, []).append(lines[j:j+4][0])
            
        d[stack_no] = d[stack_no][::-1]

    for i in range(10, len(actl_lines)):
        move = int(actl_lines[i].split()[1])
        from_ = int(actl_lines[i].split()[3])
        to = int(actl_lines[i].split()[5])

        stack_no_from = 'stack_' + str(from_)
        stack_no_to = 'stack_' + str(to)
        for item in d[stack_no_from].copy():
            if item == ' ':
                d[stack_no_from].remove(item)
        #------------SOLUTION_2-------------
        ## Remove the reversed
        for j in reversed(range(len(d[stack_no_from])-move, len(d[stack_no_from]))):
            d[stack_no_to].append(d[stack_no_from][j])
            
        del d[stack_no_from][-move:]
        
    for i in range(9):
        stack_no = 'stack_' + str(i+1)
        d[stack_no] = d[stack_no][::-1]
        
        for item in d[stack_no].copy():
            if item == ' ':
                d[stack_no].remove(item)
                
        res += d[stack_no][0]
        
    return res
    
txt_file = 'AOC_day5_input.txt'
#GRTRWNJTH wrong answ

#GRTSWNJHH right answ

supplyStacks(txt_file)
# Out:
# 'GRTSWNJHH'

# %%
grlnnmddb
from collections import defaultdict
arr1, arr2, arr3, arr4, arr5, arr6, arr7, arr8, arr9 = [], [], [], [], [], [], [], [], []

d = {}


for i in range(1, 10):

    num = 'arr_' + str(i)
    d.setdefault(num, []).append(i)

print(d)
# Out:
# {'arr_1': [1], 'arr_2': [2], 'arr_3': [3], 'arr_4': [4], 'arr_5': [5], 'arr_6': [6], 'arr_7': [7], 'arr_8': [8], 'arr_9': [9]}

# %%
a = 'hi'+ str(4)
print(a)
# Out:
# hi4

# %%
from collections import defaultdict
def supplyStacks(txt_file):
    with open(txt_file) as f:
        
        lines = f.read()
    print(lines[0:325])
#     print(lines[0:4], lines[36:40], lines[72:76])
    arr1, arr2, arr3, arr4, arr5, arr6, arr7, arr8, arr9 = [], [], [], [], [], [], [], [], []
    num = 0
    
    d = {}
#     for j in range(9):
#         for i in range(num, (num+8)*36, 36):
#             arr1.append(lines[i:i+4][1])
#         print(arr1[::-1])
#         num+=1
    for j in range(9):
        stack_no = 'stack_' + str(j+1)
#         for i in range(3):
#             d[stack_no] += i
#             print(stack_no, i)
#     print(d)

        for i in range((j*4)+1, 8*36, 36):
            d.setdefault(stack_no, []).append(lines[i:i+4][0])
            d[stack_no] = d[stack_no][::-1]
    print(d)
    d['stack_2'].append(d['stack_1'][-3:])
    print('second',d)

    
#     for i in range(1, (8)*36, 36):
#         arr1.append(lines[i:i+4][0])
# ['N', 'H', 'S', 'J', 'F', 'W', 'T', 'D']


#     for i in range(5, (8)*36, 36):
#         arr2.append(lines[i:i+4][0])
#     print(arr2[::-1])
    
#     for i in range(9, (8)*36, 36):
#         arr3.append(lines[i:i+4][0])
#     print(arr3[::-1])
    
    
#     print(lines[4:8])
#     print(lines[40:44])


#     print(arr1)
    
txt_file = 'AOC_day5_input.txt'

supplyStacks(txt_file)
# Out:
# [N] [G]                     [Q]
# [H] [B]         [B] [R]     [H]
# [S] [N]     [Q] [M] [T]     [Z]
# [J] [T]     [R] [V] [H]     [R] [S]
# [F] [Q]     [W] [T] [V] [J] [V] [M]
# [W] [P] [V] [S] [F] [B] [Q] [J] [H]
# [T] [R] [Q] [B] [D] [D] [B] [N] [N]
# [D] [H] [L] [N] [N] [M] [D] [D] [B]
#  1   2   3   4   5   6   7   8   9
#
#
# {'stack_1': ['D', 'W', 'J', 'H', 'N', 'S', 'F', 'T'], 'stack_2': ['H', 'P', 'T', 'B', 'G', 'N', 'Q', 'R'], 'stack_3': ['L', 'V', ' ', ' ', ' ', ' ', ' ', 'Q'], 'stack_4': ['N', 'S', 'R', ' ', ' ', 'Q', 'W', 'B'], 'stack_5': ['N', 'F', 'V', 'B', ' ', 'M', 'T', 'D'], 'stack_6': ['M', 'B', 'H', 'R', ' ', 'T', 'V', 'D'], 'stack_7': ['D', 'Q', ' ', ' ', ' ', ' ', 'J', 'B'], 'stack_8': ['D', 'J', 'R', 'H', 'Q', 'Z', 'V', 'N'], 'stack_9': ['B', 'H', 'S', ' ', ' ', ' ', 'M', 'N']}
# ...

# %%
# s = 'move 10 from 8 to 6'
# s = s.split()
# print(s[0])
# a = ['1','2','3','4','5','6']
# s = ''
# for i in range(len(a)-3, len(a)):
#     a.append(a[i])
# print(a)
d = {'key_1': ['hi', 'im', ' ', 'rachel','and']}
# print(d)


for item in d['key_1'].copy():
#     print(item)
    
    if item == ' ':
        d['key_1'].remove(item)
print(d['key_1'][0])


        for item in d[stack_no_from].copy():
#             print(item)
            if item == ' ':
                d[stack_no_from].remove(item)
# Out:
#   File "<ipython-input-437-1c7b3ecd7179>", line 21
#     for item in d[stack_no_from].copy():
#     ^
# IndentationError: unexpected indent

# %%
from collections import defaultdict
def supplyStacks(txt_file):
    with open(txt_file) as f:
        
        lines = f.read()
        f.seek(0)
        other = f.readlines()
    print(lines[0:325])
#     print(other)
#     print(lines[325:])
#     print(other[8])
#  1   2   3   4   5   6   7   8   9 

    
    d = {}

    for j in range(9):
        stack_no = 'stack_' + str(j+1)

        for i in range((j*4)+1, 8*36, 36):
            d.setdefault(stack_no, []).append(lines[i:i+4][0])
        d[stack_no] = d[stack_no][::-1]

#     print(d)
    
    
#     print(other[10].split())
#     print('len is ', len(other))
#     print(other[511]) last input

    for l in range(10, len(other)):
#         print(other[l].split())
    
    
        move = int(other[l].split()[1])
        from_ = int(other[l].split()[3])
        to = int(other[l].split()[5])

#     move = 
#     a = d['stack_2'][-3]
    

#     d['stack_1'].append(a)

#     s = ''
        stack_no_from = 'stack_' + str(from_)
        stack_no_to = 'stack_' + str(to)
        for item in d[stack_no_from].copy():
#             print(item)
            if item == ' ':
                d[stack_no_from].remove(item)
        for k in reversed(range(len(d[stack_no_from])-move, len(d[stack_no_from]))):
    #         print(k)
            d[stack_no_to].append(d[stack_no_from][k])
        del d[stack_no_from][-move:]
#     print(move, from_, to)
#     print(d)
    res = ''
    for m in range(9):
        stack_no = 'stack_' + str(m+1)
        d[stack_no] = d[stack_no][::-1]
        
        for item in d[stack_no].copy():
#             print(item)
            if item == ' ':
                d[stack_no].remove(item)
        res += d[stack_no][0]
#     print(d['stack_3'])
    print(d)


# for item in d['key_1'].copy():
#     print(item)
    
#     if item == ' ':
#         d['key_1'].remove(item)

    return res
    
txt_file = 'AOC_day5_input.txt'
#GRTRWNJTH wrong answ

supplyStacks(txt_file)
